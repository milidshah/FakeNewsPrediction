# %% [markdown]
# # **North Carolina Provisional Ballots Data Preparation**
#
# This notebook downloads data from the NCSBOE website about provisional ballots cast, converts the txt files to csv files, and saves the data to the data folder in the repo.
#
# **Data Source**
#
# North Carolina State Board of Elections Provisional Files: https://www.ncsbe.gov/results-data/absentee-and-provisional-data#Whatisthebestwaytojoinanabsenteefilewithanotherfile-1160

# %%
# !git config --global user.name "milidshah"
# !git config --global user.email "mili.di.shahl@gmail.com"

# %%
# comment after running once
# !git clone https://github.com/milidshah/Provisional-Ballots-NC.git
# %cd Provisional-Ballots-NC

from getpass import getpass
token = getpass("GitHub token: ")
# !git remote set-url origin https://{token}@github.com/milidshah/Provisional-Ballots-NC.git
# Out:
# Cloning into 'Provisional-Ballots-NC'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 57 (delta 18), reused 14 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 5.57 MiB | 9.70 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /content/Provisional-Ballots-NC/Provisional-Ballots-NC/Provisional-Ballots-NC/Provisional-Ballots-NC/Provisional-Ballots-NC/Provisional-Ballots-NC
# GitHub token: ··········

# %%
import pandas as pd

ballots_09_12_23 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2023_09_12/provisional_20230912.txt"
ballots_10_10_23 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2023_10_10/provisional_20231010.txt"
ballots_11_07_23 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2023_11_07/provisional_20231107.txt"
ballots_03_05_24 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2024_03_05/provisional_20240305.txt"
ballots_05_14_24 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2024_05_14/provisional_20240514.txt"
ballots_11_05_24 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2024_11_05/provisional_20241105.txt"
ballots_09_09_25 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2025_09_09/provisional_20250909.txt"
ballots_10_07_25 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2025_10_07/provisional_20251007.txt"
ballots_11_04_25 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2025_11_04/provisional_20251104.txt"
ballots_03_03_26 = "https://s3.amazonaws.com/dl.ncsbe.gov/ENRS/2026_03_03/provisional_20260303.txt"


df_09_12_23 = pd.read_csv(ballots_09_12_23, sep='\t', encoding='utf-16')
df_10_10_23 = pd.read_csv(ballots_10_10_23, sep='\t', encoding='utf-16')
df_11_07_23 = pd.read_csv(ballots_11_07_23, sep='\t', encoding='utf-16')
df_03_05_24 = pd.read_csv(ballots_03_05_24, sep='\t', encoding='utf-16')
df_05_14_24 = pd.read_csv(ballots_05_14_24, sep='\t', encoding='utf-16')
df_11_05_24 = pd.read_csv(ballots_11_05_24, sep='\t', encoding='utf-16')
df_09_09_25 = pd.read_csv(ballots_09_09_25, sep='\t', encoding='utf-16')
df_10_07_25 = pd.read_csv(ballots_10_07_25, sep='\t', encoding='utf-16')
df_11_04_25 = pd.read_csv(ballots_11_04_25, sep='\t', encoding='utf-16')
df_03_03_26 = pd.read_csv(ballots_03_03_26, sep='\t', encoding='utf-16')

# %%
import os
# save df as csv in data folder

# Save each DataFrame to CSV
df_09_12_23.to_csv("data/provisional_2023_09_12.csv", index=False)
df_10_10_23.to_csv("data/provisional_2023_10_10.csv", index=False)
df_11_07_23.to_csv("data/provisional_2023_11_07.csv", index=False)
df_03_05_24.to_csv("data/provisional_2024_03_05.csv", index=False)
df_05_14_24.to_csv("data/provisional_2024_05_14.csv", index=False)
df_11_05_24.to_csv("data/provisional_2024_11_05.csv", index=False)
df_09_09_25.to_csv("data/provisional_2025_09_09.csv", index=False)
df_10_07_25.to_csv("data/provisional_2025_10_07.csv", index=False)
df_11_04_25.to_csv("data/provisional_2025_11_04.csv", index=False)
df_03_03_26.to_csv("data/provisional_2026_03_03.csv", index=False)

print("All CSVs saved to data/")

# Push to GitHub
# !git config user.email "mili.di.shah@gmail.com"
# !git config user.name "milidshah"
# !git add data/
# !git commit -m "Add provisional ballot csv to data folder"
# !git push origin main
# Out:
# All CSVs saved to data/
# [main 4562fb5] Add provisional ballot csv to data folder
#  10 files changed, 96597 insertions(+)
#  create mode 100644 data/provisional_2023_09_12.csv
#  create mode 100644 data/provisional_2023_10_10.csv
#  create mode 100644 data/provisional_2023_11_07.csv
#  create mode 100644 data/provisional_2024_03_05.csv
#  create mode 100644 data/provisional_2024_05_14.csv
#  create mode 100644 data/provisional_2024_11_05.csv
#  create mode 100644 data/provisional_2025_09_09.csv
#  create mode 100644 data/provisional_2025_10_07.csv
#  create mode 100644 data/provisional_2025_11_04.csv
#  create mode 100644 data/provisional_2026_03_03.csv
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 676 bytes | 676.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# ...
